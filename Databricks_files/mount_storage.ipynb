# %% [markdown]
# ## Mount the following data lake storage gen2 containers
# 1. raw
# 2. processed
# 3. lookup

# %% [markdown]
# ### Set-up the configs

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "2ca31d2c-cac8-4152-ab8d-edf652aab70c",
           "fs.azure.account.oauth2.client.secret": "xz68Q~qliVRyDsjCwRhLP0O4uDvxHgeCcCwVNbkq",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/77c7ea1c-dbdb-4f47-a08b-20d2dde4ff44/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Mount the raw container

# %%
dbutils.fs.mount(
  source = "abfss://raw@ukeucovidreportingdlsa.dfs.core.windows.net/",
  mount_point = "/mnt/ukeucovidreportingdlsa/raw",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %% [markdown]
# ### Mount the processed container

# %%
dbutils.fs.mount(
  source = "abfss://processed@ukeucovidreportingdlsa.dfs.core.windows.net/",
  mount_point = "/mnt/ukeucovidreportingdlsa/processed",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %% [markdown]
# ### Mount the lookup container

# %%
dbutils.fs.mount(
  source = "abfss://lookup@ukeucovidreportingdlsa.dfs.core.windows.net/",
  mount_point = "/mnt/ukeucovidreportingdlsa/lookup",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>
